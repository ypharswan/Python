# %%
## if statement
age = 20
if age >= 18:
    print("You are allowed to caste the vote.")
# Out:
# You are allowed to caste the vote.

# %%
## else statement
age = 16
if age >= 18:
    print("YUou are eligible for voting")
else:
    print("You are minor")
# Out:
# You are minor

# %%
##elif statement
age =20
if age < 13:
    print("You are child")
elif age < 20:
    print("You are a teenager")
elif age >= 20:
    print("You are a senior")
# Out:
# You are a senior

# %%
## Nested if else statement

num = int(input("Enter a number: "))
if num > 0:
    print("The number is positive.")
    if num % 2 == 0:
        print("The number is even.")
    else:
        print("The number is odd.")
else:
    print("The number is non-positive.")
# Out:
# The number is positive.
# The number is even.

# %%
## Determine if the year is leap year 

year = int(input("Enter year: "))
if year > 0:
    if year % 4 == 0:
        print(year," is a leap year")
    else:
        print(year, " is not a leap year")
else:
    print("Please enter a valid year")
# Out:
# 2008  is a leap year

# %%
## Ticket pricing based on age and weather he is student or not

age = int(input("Please enter your age"))
is_student = input("Are you a student")
if is_student == "Yes" or is_student == "yes" or is_student == "Y" or is_student == "y":
    is_student = True
else:
    is_student = False

if age < 5:
    print("Your entry is free")
elif age >= 18:
    if is_student == True:
        print("Your ticket price is Rs 100")
    else:
        print("Your ticket price is Rs 500")
# Out:
# Your ticket price is Rs 100
